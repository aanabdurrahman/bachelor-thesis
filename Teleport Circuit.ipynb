# %%
from qiskit import(
  QuantumCircuit,
  execute,
  Aer)
from qiskit.visualization import plot_histogram

# %%
simulator = Aer.get_backend('qasm_simulator')

circuit = QuantumCircuit(3)


# Bagian EPR
circuit.x(0)
circuit.h(1)
circuit.cx(1,2)
circuit.barrier(0,1,2)

# Bagian Ani
circuit.cx(0,1)
circuit.cx(1,0)
circuit.barrier(0,1,2)

# Bagian Budi
circuit.cx(1,2)
circuit.cx(2,1)
circuit.cx(1,0)
circuit.cx(2,1)
circuit.h(0)

circuit.measure([0,1,2],[0,1,2])
job = execute(circuit, simulator, shots=1024)
result = job.result()

counts = result.get_counts(circuit)
print("\nTotal count for 00 and 11 are:",counts)
circuit.draw(output='mpl')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/qiskit/circuit/decorators.py in _convert_to_bits(a_list, bits)
#      45             try:
# ---> 46                 new_list.append(bits[item])
#      47             except IndexError:
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# QiskitError                               Traceback (most recent call last)
# <ipython-input-5-213ca394b108> in <module>
#      22 circuit.h(0)
#      23
# ---> 24 circuit.measure([0,1,2],[0,1,2])
#      25 job = execute(circuit, simulator, shots=1024)
#      26 result = job.result()
#
# /anaconda3/lib/python3.7/site-packages/qiskit/circuit/decorators.py in wrapper(self, *args)
#      74         cl_args = args[nparams + nqbits:]
#      75
# ---> 76         args = list(params) + _convert_to_bits(qb_args, qbits) + _convert_to_bits(cl_args, cbits)
#      77
#      78         return func(self, *args)
#
# /anaconda3/lib/python3.7/site-packages/qiskit/circuit/decorators.py in _convert_to_bits(a_list, bits)
#      49         elif isinstance(item, list):
#      50             # eg. circuit.h([0, 2])
# ---> 51             new_list.append(_convert_to_bits(item, bits))
#      52         elif isinstance(item, range):
#      53             # eg. circuit.h(range(0, 2))
#
# /anaconda3/lib/python3.7/site-packages/qiskit/circuit/decorators.py in _convert_to_bits(a_list, bits)
#      46                 new_list.append(bits[item])
#      47             except IndexError:
# ---> 48                 raise QiskitError("The integer param is out of range")
#      49         elif isinstance(item, list):
#      50             # eg. circuit.h([0, 2])
#
# QiskitError: 'The integer param is out of range'

# %%
plot_histogram(counts)

# %%
plot_histogram(counts)

# %%
plot_histogram(counts)

# %%
plot_histogram(counts)

# %%
plot_histogram(counts)

# %%
# Bagian EPR
cir = QuantumCircuit(2,2)

cir.h(0)
cir.cx(0,1)

cir.measure([0,1],[0,1])
job = execute(cir, simulator, shots=1024)
result1 = job1.result()

counts = result.get_counts(circuit)
print("\nTotal count for 00 and 11 are:",counts)
cir.draw(output='mpl')
# Out:
# Total count for 00 and 11 are: {'001': 509, '000': 515}
